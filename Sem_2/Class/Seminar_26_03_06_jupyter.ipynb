# %%
import requests
from bs4 import BeautifulSoup
headers = {
    "User-Agent": "Mozilla/5.0 (SeminarScraper/1.0; +https://example.org/)",
    "Accept": "text/html,application/xhtml+xml",
    "Accept-Language": "ru,en;q=0.8",
}

session = requests.Session()
session.headers.update(headers)

r1 = session.get("https://ru.wikipedia.org", headers=headers, timeout=20).text
soup = BeautifulSoup(r1, "lxml")
t = soup.find(id='main-dyk')
print("||||||||", soup, "\n", "00000000", t.text)
# Out:
# |||||||| <!DOCTYPE html>
# <html class="client-nojs skin-theme-clientpref-thumb-standard" dir="ltr" lang="ru">
# <head>
# <meta charset="utf-8"/>
# <title>Википедия — свободная энциклопедия</title>
# ...

# %%
from urllib.parse import urljoin

BASE = "https://ru.wikipedia.org"

dyk = soup.find(id='main-dyk')
print("||||", dyk.text, "||||")
link = dyk.find_all("a", href=True)
print("///", link, "///")
link = link[1]['href']
print("000", link, "000")
article_url = urljoin(BASE, link)
print(article_url)

resp_article = requests.get(article_url, headers=headers, timeout=20)

soup_article = BeautifulSoup(resp_article.text, "lxml")
title = soup_article.find("h1").get_text(strip=True)
print(title)
# Out:
# ||||
# Из новых материалов Знаете ли вы?
#
#
# Автопортрет Ахола-Вало (1924)
# Финский красноармеец (на илл.) стал одной из ключевых фигур белорусского авангарда.
# Гватемальские индейцы верят, что умершие предки посещают их при помощи воздушных змеев.
# Популярность лечения пиявками привела к почти полному их исчезновению в Западной Европе.
# У стручковой фасоли нет стручков, а у бобового корня — бобов.
# Осенний день. Сокольники
# Известный художник-передвижник назвал визитную карточку раннего Левитана (на илл.) «разноцветными штанами».
# Судьба декабристов была предсказана в поэме о племяннике Мазепы.
# В Исландии хотят восстановить леса, вырубленные при заселении острова тысячу лет назад.
# Автор «Естественной истории[англ.]» писал о животных для людей, а «Естественных историй» — чтобы порадовать самих животных.
# Иногда на скамье подсудимых оказываются даже собаки.
# Оттенки мякоти кровавых апельсинов
# ...
